# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
from IPython.display import HTML

# %%
import visualize
import world_generator
import evaluation
import projections

# %%
# enable animations to render inline.
# requires ffmpeg to be installed (`sudo apt install ffmpeg`)
rc('animation', html='html5')

# %%
N_a, M_a, g_bas = world_generator.generate_world(num_regions=256, spread_rate=0.2, self_spread_rate=2.0, large_case_count=True)
# N_a, M_a, g_ba

# %%
N_a.shape, M_a.shape, [g_ba.shape for g_ba in g_bas]
# Out:
# ((256,), (256, 256), [(64, 256), (16, 64), (4, 16), (1, 4)])

# %% [markdown]
# # Close: 10 cases; Re-open: 0.1 cases

# %%
results = evaluation.evaluate(
    M_a,
    projection_method=projections.Projections().sub_matrix_eigenvector,
    g_bas=g_bas,
    N_a_0=N_a,
    num_steps=100,
    lock_down_threshold=10,
    re_open_threshold=0.1,
    intervention_strategy=True)

# %%
anim = visualize.animate_results(results)

# %%
for i in range(len(g_bas)):
    visualize.plot_case_counts(results['N_bs'][i], results['N_bs'][i+1], 0, g_bas[i])

# %%
for i in range(len(g_bas)):
    visualize.plot_case_counts(results['N_b_hats'][i], results['N_b_hats'][i+1], 0, g_bas[i])

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
